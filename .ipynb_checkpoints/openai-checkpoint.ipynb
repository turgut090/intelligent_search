# %%
import os
from pathlib import Path
import math
import numpy as np
import pandas as pd
path = "."
photos_path = Path(path)

photos_files = [Path(os.path.join(dp, f)) for dp, dn, filenames in os.walk(photos_path) for f in filenames if os.path.splitext(f)[1] == '.jpg']

# %%
print('Image number is',len(photos_files))
# Out:
# Image number is 321693

# %%
photos_files[:5]
# Out:
# [PosixPath('imgs/id_1740851/id_1740851_9151768960207312_img.jpg'),
#  PosixPath('imgs/id_1740851/id_1740851_1047238782153548_img.jpg'),
#  PosixPath('imgs/id_1740851/id_1740851_376884936372413289_img.jpg'),
#  PosixPath('imgs/id_1740851/id_1740851_73430974428721989_img.jpg'),
#  PosixPath('imgs/id_1740851/id_1740851_408897588640409670_img.jpg'),
#  PosixPath('imgs/id_1740851/id_1740851_723494827604334095_img.jpg'),
#  PosixPath('imgs/id_1740851/id_1740851_98750361352734627_img.jpg'),
#  PosixPath('imgs/id_1740851/id_1740851_555415112567153545_img.jpg'),
#  PosixPath('imgs/id_1740851/id_1740851_411030436870917050_img.jpg'),
#  PosixPath('imgs/id_1740851/id_1740851_9435794571057414_img.jpg'),
#  PosixPath('imgs/id_1767539/id_1767539_266730642275250645_img.jpg'),
#  PosixPath('imgs/id_1767539/id_1767539_815709846510544193_img.jpg'),
#  PosixPath('imgs/id_1767539/id_1767539_504156575055507634_img.jpg'),
#  PosixPath('imgs/id_1767539/id_1767539_529003628333796135_img.jpg'),
#  PosixPath('imgs/id_1767539/id_1767539_888291911875681176_img.jpg'),
#  PosixPath('imgs/id_1767539/id_1767539_173111514136465104_img.jpg'),
#  PosixPath('imgs/id_1767539/id_1767539_497616732521958119_img.jpg'),
#  PosixPath('imgs/id_1767539/id_1767539_893225483950341780_img.jpg'),
#  PosixPath('imgs/id_1767539/id_1767539_41658130311788492_img.jpg'),
#  PosixPath('imgs/id_1711576/id_1711576_325832449528594840_img.jpg'),
#  PosixPath('imgs/id_1711576/id_1711576_65595482195577421_img.jpg'),
#  PosixPath('imgs/id_1711576/id_1711576_715016279542143539_img.jpg'),
#  PosixPath('imgs/id_1682747/id_1682747_447630204231312199_img.jpg'),
#  PosixPath('imgs/id_1682747/id_1682747_686932313961568072_img.jpg'),
#  PosixPath('imgs/id_1682747/id_1682747_490726667543951153_img.jpg')]

# %%
import clip
import torch
from PIL import Image

# Load the open CLIP model
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)
print('Device is',device)

# Function that computes the feature vectors for a batch of images
def compute_clip_features(photos_batch):
    # Load all the photos from the files
    photos = [Image.open(photo_file) for photo_file in photos_batch]
    
    # Preprocess all photos
    photos_preprocessed = torch.stack([preprocess(photo) for photo in photos]).to(device)

    with torch.no_grad():
        # Encode the photos batch to compute the feature vectors and normalize them
        photos_features = model.encode_image(photos_preprocessed)
        photos_features /= photos_features.norm(dim=-1, keepdim=True)

    # Transfer the feature vectors back to the CPU and convert to numpy
    return photos_features.cpu().numpy()
# Out:
# Device is cuda

# %%
import math
import numpy as np
import pandas as pd

# Define the batch size so that it fits on your GPU. You can also do the processing on the CPU, but it will be slower.
batch_size = 50*2

# Path where the feature vectors will be stored
features_path = Path("numpy/features") 

# Compute how many batches are needed
batches = math.ceil(len(photos_files) / batch_size)

# Process each batch
for i in range(batches):
    print(f"Processing batch {i+1}/{batches}")

    batch_ids_path = features_path / f"{i:010d}.csv"
    batch_features_path = features_path / f"{i:010d}.npy"
    
    # Only do the processing if the batch wasn't processed yet
    if not batch_features_path.exists():
        try:
            # Select the photos for the current batch
            batch_files = photos_files[i*batch_size : (i+1)*batch_size]

            # Compute the features and save to a numpy file
            batch_features = compute_clip_features(batch_files)
            np.save(batch_features_path, batch_features)

            # Save the photo IDs to a CSV file
            photo_ids = [photo_file.name.split(".")[0] for photo_file in batch_files]
            photo_ids_data = pd.DataFrame(photo_ids, columns=['photo_id'])
            photo_ids_data.to_csv(batch_ids_path, index=False)
        except:
            # Catch problems with the processing to make the process more robust
            print(f'Problem with batch {i}')
# Out:
# ing batch 5694/6434
# Processing batch 5695/6434
# Processing batch 5696/6434
# Processing batch 5697/6434
# Processing batch 5698/6434
# Processing batch 5699/6434
# Processing batch 5700/6434
# Processing batch 5701/6434
# Processing batch 5702/6434
# Processing batch 5703/6434
# Processing batch 5704/6434
# Processing batch 5705/6434
# Processing batch 5706/6434
# Processing batch 5707/6434
# Processing batch 5708/6434
# Processing batch 5709/6434
# Processing batch 5710/6434
# Processing batch 5711/6434
# Processing batch 5712/6434
# Processing batch 5713/6434
# Processing batch 5714/6434
# Processing batch 5715/6434
# Processing batch 5716/6434
# Processing batch 5717/6434
# Processing batch 5718/6434
# Processing batch 5719/6434
# Processing batch 5720/6434
# Processing batch 5721/6434
# Processing batch 5722/6434
# Processing batch 5723/6434
# Processing batch 5724/6434
# Processing batch 5725/6434
# Processing batch 5726/6434
# Processing batch 5727/6434
# Processing batch 5728/6434
# Processing batch 5729/6434
# Processing batch 5730/6434
# Processing batch 5731/6434
# Processing batch 5732/6434
# Processing batch 5733/6434
# Processing batch 5734/6434
# Processing batch 5735/6434
# Processing batch 5736/6434
# Processing batch 5737/6434
# Processing batch 5738/6434
# Processing batch 5739/6434
# Processing batch 5740/6434
# Processing batch 5741/6434
# Processing batch 5742/6434
# Processing batch 5743/6434
# Processing batch 5744/6434
# Processing batch 5745/6434
# Processing batch 5746/6434
# Processing batch 5747/6434
# Processing batch 5748/6434
# Processing batch 5749/6434
# Processing batch 5750/6434
# Processing batch 5751/6434
# Processing batch 5752/6434
# Processing batch 5753/6434
# Processing batch 5754/6434
# Processing batch 5755/6434
# Processing batch 5756/6434
# Processing batch 5757/6434
# Processing batch 5758/6434
# Processing batch 5759/6434
# Processing batch 5760/6434
# Processing batch 5761/6434
# Processing batch 5762/6434
# Processing batch 5763/6434
# Processing batch 5764/6434
# Processing batch 5765/6434
# Processing batch 5766/6434
# Processing batch 5767/6434
# Processing batch 5768/6434
# Processing batch 5769/6434
# Processing batch 6349/6434
# Processing batch 6350/6434
# Processing batch 6351/6434
# Processing batch 6352/6434
# Processing batch 6353/6434
# Processing batch 6354/6434
# Processing batch 6355/6434
# Processing batch 6356/6434
# Processing batch 6357/6434
# Processing batch 6358/6434
# Processing batch 6359/6434
# Processing batch 6360/6434
# Processing batch 6361/6434
# Processing batch 6362/6434
# Processing batch 6363/6434
# Processing batch 6364/6434
# Processing batch 6365/6434
# Processing batch 6366/6434
# Processing batch 6367/6434
# Processing batch 6368/6434
# Processing batch 6369/6434
# Processing batch 6370/6434
# Processing batch 6371/6434
# Processing batch 6372/6434
# Processing batch 6373/6434
# Processing batch 6374/6434
# Processing batch 6375/6434
# Processing batch 6376/6434
# Processing batch 6377/6434
# Processing batch 6378/6434
# Processing batch 6379/6434
# Processing batch 6380/6434
# Processing batch 6381/6434
# Processing batch 6382/6434
# Processing batch 6383/6434
# Processing batch 6384/6434
# Processing batch 6385/6434
# Processing batch 6386/6434
# Processing batch 6387/6434
# Processing batch 6388/6434
# Processing batch 6389/6434
# Processing batch 6390/6434
# Processing batch 6391/6434
# Processing batch 6392/6434
# Processing batch 6393/6434
# Processing batch 6394/6434
# Processing batch 6395/6434
# Processing batch 6396/6434
# Processing batch 6397/6434
# Processing batch 6398/6434
# Processing batch 6399/6434
# Processing batch 6400/6434
# Processing batch 6401/6434
# Processing batch 6402/6434
# Processing batch 6403/6434
# Processing batch 6404/6434
# Processing batch 6405/6434
# Processing batch 6406/6434
# Processing batch 6407/6434
# Processing batch 6408/6434
# Processing batch 6409/6434
# Processing batch 6410/6434
# Processing batch 6411/6434
# Processing batch 6412/6434
# Processing batch 6413/6434
# Processing batch 6414/6434
# Processing batch 6415/6434
# Processing batch 6416/6434
# Processing batch 6417/6434
# Processing batch 6418/6434
# Processing batch 6419/6434
# Processing batch 6420/6434
# Processing batch 6421/6434
# Processing batch 6422/6434
# Processing batch 6423/6434
# Processing batch 6424/6434
# Processing batch 6425/6434
# Processing batch 6426/6434
# Processing batch 6427/6434
# Processing batch 6428/6434
# Processing batch 6429/6434
# Processing batch 6430/6434
# Processing batch 6431/6434
# Processing batch 6432/6434
# Processing batch 6433/6434
# Processing batch 6434/6434

# %%
import numpy as np
import pandas as pd

# Load all numpy files
#features_list = [np.load(features_file) for features_file in sorted(features_path.glob("nummpy/*.npy"))]
features_list =  [Path(os.path.join(dp, f)) for dp, dn, filenames in os.walk(Path('numpy/features')) for f in filenames if os.path.splitext(f)[1] == '.npy']

features_list = [np.load(features_file) for features_file in sorted(features_list)]

# Concatenate the features and store in a merged file
features = np.concatenate(features_list)
np.save(features_path / "features.npy", features)

# Load all the photo IDs
#csv_list =  [Path(os.path.join(dp, f)) for dp, dn, filenames in os.walk(Path('numpy/features')) for f in filenames if os.path.splitext(f)[1] == '.csv']

#photo_ids = pd.concat([pd.read_csv(ids_file) for ids_file in sorted(csv_list)])
#photo_ids.to_csv(features_path / "photo_ids.csv", index=False)
